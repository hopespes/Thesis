# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.14/site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in ./venv/lib/python3.14/site-packages (from pandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob

# %%
import pandas as pd
import glob

# %%
vanilla_files = glob.glob('../results/vanilla_alpha_zero_28/logs/go/9x9/actor*.csv')
vanilla_combined = pd.concat([pd.read_csv(f) for f in vanilla_files], ignore_index=True)

n_games = vanilla_combined.shape[0]
n_states = vanilla_combined["game_length"].sum()
n_sim = n_games * 200
sim_p_situation = n_sim / n_games
median_sim = 200
vanilla_data = [n_games, n_states, n_sim, median_sim, sim_p_situation]

# %%
#rl_files = glob.glob('../results/rl_alpha_zero_28/logs/go/9x9/actor*.csv')
#rl_combined = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)

# %%
# Print to file
data = pd.DataFrame({
    'vanilla': vanilla_data
})

data.to_csv("data.csv", index=False)
